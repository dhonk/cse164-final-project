# %% [markdown]
# # CSE 164 Final Project

# %%
from pathlib import Path

import torch
import numpy as np
from PIL import Image

import src.utils as utils
import src.dataset as datasets

# Constants
DATA_DIR = "./data"

# %% [markdown]
# ### Checking src.dataset

# %%
# Check Loading Metadata
datasets.load_metadata(DATA_DIR, "train_labeled")[:5]
# Out:
# [{'class_id': 0, 'image': 'train_labeled/images/labeled_000_000.JPEG'},
#  {'class_id': 0, 'image': 'train_labeled/images/labeled_000_001.JPEG'},
#  {'class_id': 0, 'image': 'train_labeled/images/labeled_000_002.JPEG'},
#  {'class_id': 0, 'image': 'train_labeled/images/labeled_000_003.JPEG'},
#  {'class_id': 0, 'image': 'train_labeled/images/labeled_000_004.JPEG'}]

# %%
datasets.load_metadata(DATA_DIR, "train_seg")[:5]
# Out:
# [{'class_id': 0,
#   'image': 'train_seg/images/seg_000_000.JPEG',
#   'mask': 'train_seg/masks/seg_000_000.png',
#   'segmentation_id': 1},
#  {'class_id': 0,
#   'image': 'train_seg/images/seg_000_001.JPEG',
#   'mask': 'train_seg/masks/seg_000_001.png',
#   'segmentation_id': 1},
#  {'class_id': 0,
#   'image': 'train_seg/images/seg_000_002.JPEG',
#   'mask': 'train_seg/masks/seg_000_002.png',
#   'segmentation_id': 1},
#  {'class_id': 0,
#   'image': 'train_seg/images/seg_000_003.JPEG',
#   'mask': 'train_seg/masks/seg_000_003.png',
#   'segmentation_id': 1},
#  {'class_id': 0,
#   'image': 'train_seg/images/seg_000_004.JPEG',
#   'mask': 'train_seg/masks/seg_000_004.png',
#   'segmentation_id': 1}]

# %%
datasets.load_metadata(DATA_DIR, "class_map")[:5]
# Out:
# [{'class_id': 0, 'name': 'class_000', 'segmentation_id': 1},
#  {'class_id': 1, 'name': 'class_001', 'segmentation_id': 2},
#  {'class_id': 2, 'name': 'class_002', 'segmentation_id': 3},
#  {'class_id': 3, 'name': 'class_003', 'segmentation_id': 4},
#  {'class_id': 4, 'name': 'class_004', 'segmentation_id': 5}]

# %%
# Check labeled dataset for training classification
train_labeled = datasets.TrainLabeledDataset(DATA_DIR)
train_labeled[0]

# Sanity check: compare PIL image and the actual JPEG
for i in range(0, 150, 15):
    pil_img, label, fname = train_labeled[i]
    img = mpimg.imread(Path(DATA_DIR) / "train_labeled" / "images" / fname)
    plt.figure(figsize=(2,2))
    plt.imshow(img)
    plt.axis("off")
    plt.show()
    pil_img
